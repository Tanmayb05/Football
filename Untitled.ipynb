# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mplsoccer.pitch import Pitch

# %%
df = pd.read_csv('messibetis.csv')
df
# Out:
#    player  minute  second    x    y  type       outcome  endX  endY
# 0   messi      45       0   50   50  Pass    Successful    40    43
# 1   messi      45      25   63   48  Pass    Successful    75    83
# 2   messi      46       4   74   58  Pass    Successful    71    65
# 3   messi      46       7   76   68  Pass    Successful    95    78
# 4   messi      46      55  100    1  Pass  Unsuccessful    96    38
# 5   messi      47      42   73   25  Pass    Successful    70    54
# 6   messi      49      47   75   43  Pass  Unsuccessful    82    38
# 7   messi      50      10   79   31  Pass    Successful    87    24
# 8   messi      50      17   82   52  Pass    Successful    93    68
# 9   messi      50      24   98   62  Pass  Unsuccessful    98    61
# 10  messi      55      22   30   12  Pass    Successful    22    24
# 11  messi      56      24   38   42  Pass    Successful    37    51
# 12  messi      56      36   53   44  Pass    Successful    43    62
# ...

# %%
# Convert x & y to match it to mplsoccer pitch

df['x']    = df['x'] * 1.2
df['y']    = df['y'] * 1.8
df['endX'] = df['endX'] * 1.2
df['endY'] = df['endY'] * 1.8
df
# Out:
#    player  minute  second      x      y  type       outcome   endX   endY
# 0   messi      45       0   60.0   90.0  Pass    Successful   48.0   77.4
# 1   messi      45      25   75.6   86.4  Pass    Successful   90.0  149.4
# 2   messi      46       4   88.8  104.4  Pass    Successful   85.2  117.0
# 3   messi      46       7   91.2  122.4  Pass    Successful  114.0  140.4
# 4   messi      46      55  120.0    1.8  Pass  Unsuccessful  115.2   68.4
# 5   messi      47      42   87.6   45.0  Pass    Successful   84.0   97.2
# 6   messi      49      47   90.0   77.4  Pass  Unsuccessful   98.4   68.4
# 7   messi      50      10   94.8   55.8  Pass    Successful  104.4   43.2
# 8   messi      50      17   98.4   93.6  Pass    Successful  111.6  122.4
# 9   messi      50      24  117.6  111.6  Pass  Unsuccessful  117.6  109.8
# 10  messi      55      22   36.0   21.6  Pass    Successful   26.4   43.2
# 11  messi      56      24   45.6   75.6  Pass    Successful   44.4   91.8
# ...

# %%
pitch = Pitch(
    pitch_type='statsbomb', 
    pitch_color='#22312b', 
    line_color='white',
    constrained_layout = True,
    tight_layout = False,
    figsize = (16,11))

fig, ax = pitch.draw()

# X-axis = 
# Y-axis =
